# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df= pd.read_csv ("./datasets/TopFree.csv")
df.head()
# Out:
#       Unnamed: 0    080516  080416    080316    080216  080116  073116  \
# 0      messenger  29256317      -1  29179154  29158064      -1      -1
# 1    go security    224916      -1    214534    209427      -1      -1
# 2       snapchat   7856978      -1   7830609   7814898      -1      -1
# 3       facebook  46203511      -1  46069529  46018776      -1      -1
# 4  spotify music   5931160      -1   5916865   5909308      -1      -1
#
#    073016    072916    072816  ...    062716  062616  062516    062416  \
# 0      -1  29000187  28965091  ...  27847756      -1      -1  27716342
# 1      -1    185337    180797  ...     95427      -1      -1     91353
# 2      -1   7759750   7745601  ...   7245690      -1      -1   7200015
# 3      -1  45803130  45749710  ...  43972389      -1      -1  43755932
# 4      -1   5877553   5869074  ...   5615475      -1      -1   5588681
#
#      062316    062216    062116    062016  061916    061816
# 0  27675185  27639407  27600355  27554065      -1  27498432
# 1     90228     88855     87486     83378      -1     78369
# 2   7187280   7172863   7159379   7148444      -1   7132134
# 3  43676649  43614012  43550673  43498434      -1  43416153
# 4   5580977   5573552   5566644   5559821      -1   5550310
#
# [5 rows x 50 columns]

# %%
print(df ['080516'].describe())
# Out:
# count    1.124000e+03
# mean     7.837127e+05
# std      3.252122e+06
# min     -1.000000e+00
# 25%     -1.000000e+00
# 50%     -1.000000e+00
# 75%      2.958240e+05
# max      4.620351e+07
# Name: 080516, dtype: float64

# %%
#import matplotlib.pyplot as plt
#import pandas as pd
#import seaborn as sns
#df= pd.read_csv ("cell 1.csv")
plt.figure(figsize=(6,4))

sns.histplot(data=df,y='080516', kde=True)
plt.title('distribucion')
plt.savefig("migrafico.png")
plt.show()
